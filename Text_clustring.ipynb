# %% [markdown]
# <a href="https://colab.research.google.com/github/hghri/DataScience/blob/main/Text_clustring.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df =pd.read_csv('/content/JEOPARDY_CSV.csv')

# %%
df.head()
# Out:
#    Show Number    Air Date      Round                         Category  Value  \
# 0         4680  2004-12-31  Jeopardy!                          HISTORY   $200
# 1         4680  2004-12-31  Jeopardy!  ESPN's TOP 10 ALL-TIME ATHLETES   $200
# 2         4680  2004-12-31  Jeopardy!      EVERYBODY TALKS ABOUT IT...   $200
# 3         4680  2004-12-31  Jeopardy!                 THE COMPANY LINE   $200
# 4         4680  2004-12-31  Jeopardy!              EPITAPHS & TRIBUTES   $200
#
#                                             Question      Answer
# 0  For the last 8 years of his life, Galileo was ...  Copernicus
# 1  No. 2: 1912 Olympian; football star at Carlisl...  Jim Thorpe
# 2  The city of Yuma in this state has a record av...     Arizona
# 3  In 1963, live on "The Art Linkletter Show", th...  McDonald's
# 4  Signer of the Dec. of Indep., framer of the Co...  John Adams

# %%
X = df[[' Question']]

# %%
X.dtypes
# Out:
#  Question    object
# dtype: object

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorizer=TfidfVectorizer()
vectorizer.fit(X)
# Out:
# TfidfVectorizer()

# %%
X=vectorizer.transform(X)

# %%
from sklearn.cluster import KMeans

# %%
km=KMeans(n_clusters=10,max_iter=300)

# %%
km.fit(X)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-e41873a7fbf2> in <cell line: 1>()
# ----> 1 km.fit(X)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py in fit(self, X, y, sample_weight)
#    1424         )
#    1425
# -> 1426         self._check_params_vs_input(X)
#    1427
#    1428         random_state = check_random_state(self.random_state)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py in _check_params_vs_input(self, X)
#    1360
#    1361     def _check_params_vs_input(self, X):
# -> 1362         super()._check_params_vs_input(X, default_n_init=10)
#    1363
#    1364         self._algorithm = self.algorithm
#
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py in _check_params_vs_input(self, X, default_n_init)
#     857         # n_clusters
#     858         if X.shape[0] < self.n_clusters:
# ...

# %%
from sklearn.metrics import silhouette_score

# %%
silhouette_score(X,km.labels_)
# Out:
# 0.007295237418467201

# %%
with open('stopwords.txt') as stopwords_file:
    stopwords = stopwords_file.readlines()
stopwords = [line.replace('\n', '') for line in stopwords]
stopwords
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  "can't",
#  'cannot',
#  'could',
#  "couldn't",
#  'did',
#  "didn't",
#  'do',
#  'does',
#  "doesn't",
#  'doing',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  "hadn't",
#  'has',
#  "hasn't",
#  'have',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  "he's",
#  'her',
#  'here',
#  "here's",
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  "how's",
#  'i',
#  "i'd",
#  "i'll",
#  "i'm",
#  "i've",
#  'if',
#  'in',
#  'into',
#  'is',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  "let's",
#  'me',
#  'more',
#  'most',
#  "mustn't",
#  'my',
#  'myself',
#  'no',
#  'nor',
#  'not',
#  'of',
#  'off',
# ...

# %%
import re
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
len(stopwords)
# Out:
# 2140

# %%
nltk_stopwords=nltk.corpus.stopwords.words('english')
stopwords.extend(nltk_stopwords)

# %%
from nltk import word_tokenize
nltk.download('punkt')
dataset=pd.DataFrame(columns=['title_body'])
for index ,row in X.iterrows():
  title_body_tokenized = word_tokenize(row[' Question'])
  title_body_tokenized_filtered=[w.lower() for w in title_body_tokenized if not w.lower() in stopwords]
  s = re.sub('[^\w\s]', '', ' '.join(title_body_tokenized_filtered))
  s = re.sub("\d+", "", s)
  dataset.loc[index] = {
        'title_body': s,
    }
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
dataset
# Out:
#                                                title_body
# 0           life  galileo house arrest espousing s theory
# 1           olympian  football star carlisle indian sc...
# 2                city yuma record average  hours sunshine
# 3         live  art linkletter   company served billio...
# 4       signer dec indep  framer constitution mass  pr...
# ...                                                   ...
# 216925      puccini opera solution  riddles posed heroine
# 216926  north america term properly applied  species c...
# 216927  penny lane   hellraiser  grew  barber shaves c...
# 216928  ft sill  okla plea  arizona land   father s la...
# 216929  silent movie title includes th c statesman  fa...
#
# [216930 rows x 1 columns]

# %%
import pickle
with open('dataset.pickle', 'wb') as file:
    pickle.dump(dataset, file)

# %%
import pickle

# %%
with open('dataset.pickle','rb') as file:
  dataset=pickle.load(file)

# %%
dataset
# Out:
#                                                title_body
# 0           life  galileo house arrest espousing s theory
# 1           olympian  football star carlisle indian sc...
# 2                city yuma record average  hours sunshine
# 3         live  art linkletter   company served billio...
# 4       signer dec indep  framer constitution mass  pr...
# ...                                                   ...
# 216925      puccini opera solution  riddles posed heroine
# 216926  north america term properly applied  species c...
# 216927  penny lane   hellraiser  grew  barber shaves c...
# 216928  ft sill  okla plea  arizona land   father s la...
# 216929  silent movie title includes th c statesman  fa...
#
# [216930 rows x 1 columns]

# %%
X=dataset['title_body']

# %%
X.shape
# Out:
# (216930,)

# %%
vectorizer=TfidfVectorizer()
vectorizer.fit(X)
# Out:
# TfidfVectorizer()

# %%
X=vectorizer.transform(X)

# %%
X
# Out:
# <216930x93493 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1429996 stored elements in Compressed Sparse Row format>

# %%
km=KMeans(n_clusters=12,init='k-means++',max_iter=500)

# %%
km.fit(X)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(max_iter=500, n_clusters=12)

# %%
km.inertia_
# Out:
# 212867.08904080113

# %%
dataset['Km_labels']=km.labels_

# %%
dataset
# Out:
#                                                title_body  Km_labels
# 0           life  galileo house arrest espousing s theory          5
# 1           olympian  football star carlisle indian sc...          5
# 2                city yuma record average  hours sunshine          8
# 3         live  art linkletter   company served billio...          5
# 4       signer dec indep  framer constitution mass  pr...          5
# ...                                                   ...        ...
# 216925      puccini opera solution  riddles posed heroine          5
# 216926  north america term properly applied  species c...          5
# 216927  penny lane   hellraiser  grew  barber shaves c...          5
# 216928  ft sill  okla plea  arizona land   father s la...          5
# 216929  silent movie title includes th c statesman  fa...          4
#
# [216930 rows x 2 columns]

# %%
from collections import Counter
Counter(" ".join(dataset[dataset['Km_labels'] == 0]["title_body"]).split()).most_common(50)
# Out:
# [('born', 2069),
#  ('s', 314),
#  ('city', 122),
#  ('died', 119),
#  ('country', 87),
#  ('president', 80),
#  ('named', 67),
#  ('us', 64),
#  ('son', 56),
#  ('capital', 51),
#  ('author', 44),
#  ('july', 44),
#  ('king', 42),
#  ('famous', 41),
#  ('england', 40),
#  ('day', 40),
#  ('star', 39),
#  ('sign', 39),
#  ('nt', 38),
#  ('woman', 38),
#  ('age', 35),
#  ('father', 35),
#  ('wrote', 35),
#  ('john', 34),
#  ('th', 34),
#  ('st', 33),
#  ('island', 32),
#  ('american', 31),
#  ('re', 31),
#  ('family', 29),
#  ('married', 28),
#  ('march', 28),
#  ('people', 28),
#  ('town', 27),
#  ('time', 27),
#  ('feb', 27),
#  ('english', 26),
#  ('child', 26),
#  ('leader', 26),
#  ('west', 25),
#  ('april', 25),
#  ('bc', 24),
#  ('british', 23),
#  ('daughter', 23),
#  ('south', 23),
#  ('york', 23),
#  ('called', 23),
#  ('film', 23),
#  ('parents', 22),
#  ('french', 22)]
